# %%
print (" //\ ")
print ("//__\ ")
print ("||  ||")
print ("||__||")
# Out:
#  //\
# //__\
# ||  ||
# ||__||

# %%
nombre = input ("Escibre tu nombre:")
print(f" BIENVENIDO! {nombre}")
print ("Escribe tu correo")
input ()
print ("Ecribe tu numero")
input  ()
# Out:
# Escibre tu nombre: miguel
#  BIENVENIDO! miguel
# Escribe tu correo
#  migue@gmail.com
# Ecribe tu numero
#  5537625712
# '5537625712'

# %%
r1 = int (input ("ingresar el valor de la resistencia:"))
r2 = int (input ("ingresar el valor de la resistencia:"))
rt = 1/  ((1/r1)+(1/r2))
print ("total:", rt)
# Out:
# ingresar el valor de la resistencia: 26
# ingresar el valor de la resistencia: 26
# total: 13.0

# %%
import numpy as np 
m = np.array([[4,3][8,9]])	
array([[4,3]
          [8,9]])
np.linalg.det(m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-cc3af377ab8a> in <module>
#       1 import numpy as np
# ----> 2 m = np.array([[4,3][8,9]])
#       3 array([[4,3]
#       4           [8,9]])
#       5 np.linalg.det(m)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
a=float(input("Valor a:"))
b=float(input("Valor b:"))
c=float(input("Valor c:"))
if a!=0:
    x1=(-b+(((b**2)-(4*a*c))**0.5))/(2*a)
    x2=(-b-(((b**2)-(4*a*c))**0.5))/(2*a)
    print("el valor de x1 es:")
    print(x1)
    print("el valor de x2 es:")
    print(x2)
# Out:
# Valor a: 15
# Valor b: 15
# Valor c: 16
# el valor de x1 es:
# (-0.49999999999999994+0.9036961141150639j)
# el valor de x2 es:
# (-0.5000000000000001-0.9036961141150639j)

# %%
numero_como_cadena = input("Escribe un número: ")
numero = float(numero_como_cadena)
if numero == 0:
    print("Cero")
elif numero < 0:
    print("Negativo")
else:
    print("Positivo")
# Out:
# Escribe un número:  5
# Positivo

# %%
def _cuentas(prestamo,meses):
    cuota = prestamo/meses
    return cuota
def _Prestamo():
    prestamo = input("Monto de tu prestamo? ")
    meses= input("En cuantos meses deseas pagar? ")
    print ("Monto de pago por mes es: ",_cuentas(prestamo,meses))
edad= int (input ("Dame tu edad: "))
if edad >= 18:
    ingresos=int(input("Dame tus ingresos: "))
    egresos=int(input("Dame tus egresos: "))
    if ingresos >= egresos:
       
    _Prestamo()
    else:
        print("Sus ingresos deben ser mayores.")
else:
    print ("No eres mayor de edad.")
# Out:
#   File "<ipython-input-9-7bde05c9860e>", line 14
#     _Prestamo()
#             ^
# IndentationError: expected an indented block

# %%
row = int(input("ingresa el numeor de extrellas"))
for i in range (row):
    print (" *"*(i+1))
for j in range (row):
    print (" *"*(row-j-1))
# Out:
# ingresa el numeor de extrellas 15
#  *
#  * *
#  * * *
#  * * * *
#  * * * * *
#  * * * * * *
#  * * * * * * *
#  * * * * * * * *
#  * * * * * * * * *
#  * * * * * * * * * *
#  * * * * * * * * * * *
#  * * * * * * * * * * * *
#  * * * * * * * * * * * * *
#  * * * * * * * * * * * * * *
#  * * * * * * * * * * * * * * *
#  * * * * * * * * * * * * * *
#  * * * * * * * * * * * * *
#  * * * * * * * * * * * *
#  * * * * * * * * * * *
#  * * * * * * * * * *
#  * * * * * * * * *
#  * * * * * * * *
#  * * * * * * *
#  * * * * * *
#  * * * * *
#  * * * *
#  * * *
#  * *
#  *

# %%
palabra=[]
palabra=input("Ingresar la palabra a invertir: ")
arbarlap=""
for i in palabra:
    arbarlap=i+arbarlap 
    print (arbarlap)
# Out:
# Ingresar la palabra a invertir:  miguel
# m
# im
# gim
# ugim
# eugim
# leugim

# %%
n=0
print(n)
for n in range (7):
    if n%3!=0:
        print (n)
# Out:
# 0
# 1
# 2
# 4
# 5
