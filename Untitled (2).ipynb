# %%
print (" //\ ")
print ("//__\ ")
print ("||  ||")
print ("||__||")
# Out:
#  //\
# //__\
# ||  ||
# ||__||

# %%
nombre = input ("Escibre tu nombre:")
print(f" BIENVENIDO! {nombre}")
print ("Escribe tu correo")
input ()
print ("Ecribe tu numero")
input  ()
# Out:
# Escibre tu nombre: miguel
#  BIENVENIDO! miguel
# Escribe tu correo
#  MIG@29.COM
# Ecribe tu numero
#  5537625712
# '5537625712'

# %% [markdown]
# ##### r1 = int (input ("ingresar el valor de la resistencia:"))
# r2 = int (input ("ingresar el valor de la resistencia:"))
# rt = 1/  ((1/r1)+(1/r2))
# print ("total:", rt)

# %%
r1 = int (input ("ingresar el valor de la resistencia:"))
r2 = int (input ("ingresar el valor de la resistencia:")) rt = 1/ ((1/r1)+(1/r2)) print ("total:", rt)
# Out:
#   File "<ipython-input-4-1d338d5d2a51>", line 2
#     r2 = int (input ("ingresar el valor de la resistencia:")) rt = 1/ ((1/r1)+(1/r2)) print ("total:", rt)
#                                                                ^
# SyntaxError: invalid syntax

# %%
import numpy as np 
m = np.array([[4,3][8,9]])


 
np.linalg.det(m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-d19e28a47df8> in <module>
#       1 import numpy as np
# ----> 2 m = np.array([[4,3][8,9]])
#       3
#       4
#       5
#
# TypeError: list indices must be integers or slices, not tuple

# %%
a=float(input("Valor a:"))
b=float(input("Valor b:"))
c=float(input("Valor c:"))
if a!=0:
    x1=(-b+(((b**2)-(4*a*c))**0.5))/(2*a)
    x2=(-b-(((b**2)-(4*a*c))**0.5))/(2*a)
    print("el valor de x1 es:")
    print(x1)
    print("el valor de x2 es:")
    print(x2)
# Out:
# Valor a: 5
# Valor b: 6
# Valor c: 4
# el valor de x1 es:
# (-0.6+0.6633249580710799j)
# el valor de x2 es:
# (-0.6-0.6633249580710799j)

# %% [markdown]
# ##### numero_como_cadena = input("Escribe un número: ")
# numero = float(numero_como_cadena)
# if numero == 0:
#     print("Cero")
# elif numero < 0:
#     print("Negativo")
# else:
#     print("Positivo")

# %%
numero_como_cadena = input("Escribe un número: ")
numero = float(numero_como_cadena)
if numero == 0:
    print("Cero")
elif numero < 0:
    print("Negativo")
else:
    print("Positivo")
# Out:
# Escribe un número:  0
# Cero

# %%
def cuentas(prestamo,meses):
    cuota=prestamo/meses
    return cuota
def Prestamo():
    prestamo= input("Monto de tu prestamo? ")
    meses= input("En cuantos meses deseas pagar? ")
    print ("Monto de pago por mes es: ",cuentas(prestamo,meses))
edad= int (input ("Dame tu edad: "))
if edad >= 18:
    ingresos=int(input("Dame tus ingresos: "))
    egresos=int(input("Dame tus egresos: "))
    if ingresos >= egresos:
        


    Prestamo()
    else:
        print("Sus ingresos deben ser mayores.")
else:
    print ("No eres mayor de edad.")
# Out:
#   File "<ipython-input-54-b07ad7b491d7>", line 16
#     Prestamo()
#            ^
# IndentationError: expected an indented block

# %%
def _cuentas(prestamo,meses):
    cuota=prestamo/meses
    return cuota
def _Prestamo():
    prestamo= input("Monto de tu prestamo? ")
    meses= input("En cuantos meses deseas pagar? ")
    print ("Monto de pago por mes es: ",_cuentas(prestamo,meses))
edad= int (input ("Dame tu edad: "))
if edad >= 18:
    ingresos=int(input("Dame tus ingresos: "))
    egresos=int(input("Dame tus egresos: "))
    if ingresos >= egresos:
        
_Prestamo()
    else:
        print("Sus ingresos deben ser mayores.")
else:
    print ("No eres mayor de edad.")
# Out:
#   File "<ipython-input-23-da7a0ac37ffe>", line 14
#     _Prestamo()
#                ^
# IndentationError: expected an indented block

# %%
row = int(input("ingresa el numeor de extrellas"))
for i in range (row):
    print (" *"*(i+1))
for j in range (row):
    print (" *"*(row-j-1))
# Out:
# ingresa el numeor de extrellas 15
#  *
#  * *
#  * * *
#  * * * *
#  * * * * *
#  * * * * * *
#  * * * * * * *
#  * * * * * * * *
#  * * * * * * * * *
#  * * * * * * * * * *
#  * * * * * * * * * * *
#  * * * * * * * * * * * *
#  * * * * * * * * * * * * *
#  * * * * * * * * * * * * * *
#  * * * * * * * * * * * * * * *
#  * * * * * * * * * * * * * *
#  * * * * * * * * * * * * *
#  * * * * * * * * * * * *
#  * * * * * * * * * * *
#  * * * * * * * * * *
#  * * * * * * * * *
#  * * * * * * * *
#  * * * * * * *
#  * * * * * *
#  * * * * *
#  * * * *
#  * * *
#  * *
#  *

# %%
palabra=[]
palabra=input(“Ingresar la palabra a invertir:”)
# Out:
#   File "<ipython-input-25-701227424420>", line 2
#     palabra=input(“Ingresar la palabra a invertir:”)
#                           ^
# SyntaxError: invalid character in identifier

# %%
palabra=[]
palabra=input(“Ingresar la palabra a invertir:”)
arbol=""
for i in palabra:
# Out:
#   File "<ipython-input-26-24f29b0a4054>", line 2
#     palabra=input(“Ingresar la palabra a invertir:”)
#                           ^
# SyntaxError: invalid character in identifier

# %%
palabra=[]
palabra=input(“Ingresar la palabra a invertir:”)
arbol=""
for i in palabra:
    arbol=i+ arbol 
    print (arbol )
# Out:
#   File "<ipython-input-27-4e778386e190>", line 2
#     palabra=input(“Ingresar la palabra a invertir:”)
#                           ^
# SyntaxError: invalid character in identifier

# %%
palabra=[]
palabra=input("Ingresar la palabra a invertir: ")
arbol=""
for i in palabra:
    arbol=i+ arbol 
    print (arbol )
# Out:
# Ingresar la palabra a invertir:  miguel
# m
# im
# gim
# ugim
# eugim
# leugim

# %%
palabra=[]
palabra=input("Ingresar la palabra a invertir: ")
arbarlap=""
for i in palabra:
    arbarlap=i+arbarlap 
    print (arbarlap)
# Out:
# Ingresar la palabra a invertir:  miguel
# m
# im
# gim
# ugim
# eugim
# leugim
#  leugim

# %%
n=0
print(n)
for n in range (7):
if n%3!=0:
print (n)
# Out:
#   File "<ipython-input-30-58e92cce3a6e>", line 4
#     if n%3!=0:
#      ^
# IndentationError: expected an indented block

# %%
n=0
print(n)
for n in range (7):
if n %3!=0:
print (n)
# Out:
#   File "<ipython-input-31-ad6758c05196>", line 4
#     if n %3!=0:
#      ^
# IndentationError: expected an indented block

# %%
n=0
print(n)
for n in range (7):
if n % 3!= 0:
print (n)
# Out:
#   File "<ipython-input-32-82540b468ece>", line 4
#     if n % 3!= 0:
#      ^
# IndentationError: expected an indented block

# %%
n=0
print(n)
for n in range (7):
    if n%3!=0:
    print(n)
# Out:
#   File "<ipython-input-33-20359fadc673>", line 5
#     print(n)
#         ^
# IndentationError: expected an indented block

# %%
n=0
print(n)
for n in range (7):
    if n%3!=0:
        print(n)
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
def 
_cuentas(prestamo,meses):
    cuota=prestamo/meses
    return cuota
def _Prestamo():
    prestamo= input("Monto de tu prestamo? ")
    meses= input("En cuantos meses deseas pagar? ")
    print ("Monto de pago por mes es:"
           ,_cuentas(prestamo,meses))
edad= int (input ("Dame tu edad: "))
if edad >= 18:
    ingresos=int(input("Dame tus ingresos: "))
    egresos=int(input("Dame tus egresos: "))
    if ingresos >= egresos:
       
      _Prestamo()
    else:
        print("Sus ingresos deben ser mayores.")
    else:
        print ("No eres mayor de edad.")
# Out:
#   File "<ipython-input-35-e7d846be06de>", line 1
#     def
#         ^
# SyntaxError: invalid syntax

# %%
def 
_cuentas(prestamo,meses):
    cuota=prestamo/meses
    return cuota
def
_Prestamo():
    prestamo= input("Monto de tu prestamo? ")
    meses= input("En cuantos meses deseas pagar? ")
    print ("Monto de pago por mes es:"
           ,_cuentas(prestamo,meses))
edad= int (input ("Dame tu edad: "))
if edad >= 18:
    ingresos=int(input("Dame tus ingresos: "))
    egresos=int(input("Dame tus egresos: "))
    if ingresos >= egresos:
       
      _Prestamo()
    else:
        print("Sus ingresos deben ser mayores.")
    else:
        print ("No eres mayor de edad.")
# Out:
#   File "<ipython-input-36-432c2d3bffe0>", line 1
#     def
#         ^
# SyntaxError: invalid syntax

# %%
def _cuentas(prestamo,meses):
    cuota=prestamo/meses
    return cuota
def _Prestamo():
    prestamo= input("Monto de tu prestamo? ")
    meses= input("En cuantos meses deseas pagar? ")
    print ("Monto de pago por mes es:"
           ,_cuentas(prestamo,meses))
edad= int (input ("Dame tu edad: "))
if edad >= 18:
    ingresos=int(input("Dame tus ingresos: "))
    egresos=int(input("Dame tus egresos: "))
    if ingresos >= egresos:
       
      _Prestamo()
else:
        print("Sus ingresos deben ser mayores.")
else:
        print ("No eres mayor de edad.")
# Out:
#   File "<ipython-input-37-f1babb2b76f3>", line 18
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
def _cuentas(prestamo,meses):
    cuota=prestamo/meses
    return cuota
def _Prestamo():
    prestamo= input("Monto de tu prestamo? ")
    meses= input("En cuantos meses deseas pagar? ")
    print ("Monto de pago por mes es:"
           ,_cuentas(prestamo,meses))
edad= int (input ("Dame tu edad: "))
if edad >= 18:
    ingresos=int(input("Dame tus ingresos: "))
    egresos=int(input("Dame tus egresos: "))
    if ingresos >= egresos:
       
           _Prestamo()
else:
     print("Sus ingresos deben ser mayores.")
else:
      print ("No eres mayor de edad.")
# Out:
#   File "<ipython-input-53-3c435f7020e4>", line 18
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
import numpy as np
m = np.array([[4,3][8,9]])
np.linalg.det (m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-403427b26089> in <module>
#       1 import numpy as np
# ----> 2 m = np.array([[4,3][8,9]])
#       3 np.linalg.det (m)
#       4
#
# TypeError: list indices must be integers or slices, not tuple
